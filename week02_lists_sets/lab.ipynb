# %% [markdown]
# # IST1012 – Computer Programming II
# ## Week 2 Lab – Python Data Types, Lists, and Sets
#
# Follow the instructions in each cell.
#
# Write your code where requested.
#
# Do not skip tasks.

# %% [markdown]
# ## Task 1 – Variables and Data Types
#
# Create variables that store the following information:
#
# - A student's name
# - A student's age
# - A student's height
# - Whether the student is enrolled in this course
#
# Then print all variables.
#
# Observe the output.

# %%
student_name = "Ceylin Güven"
student_age = 19
student_height = 1.68
is_enrolled = True
print(student_name)
print(student_age)
print(student_height)
print(is_enrolled)
type(student_name)
type(student_age)
type(student_height)
type(is_enrolled)
# Out:
# Ceylin Güven
# 19
# 1.68
# True
# bool

# %% [markdown]
# ## Task 2 – Input and Type Conversion
#
# Write a program that asks the user to enter:
#
# - Their name
# - Their age
# - Their favorite programming language
#
# After collecting the information, print:
#
# - The name
# - The age next year
# - The favorite programming language

# %%
name = input("enter your name")
age = int(input("enter your age"))
f_prog_lang = input("enter your favorite programming language")

print("Name:", name)
print("Age next year", age + 1)
print("fav language",)
# Out:
#   File "/tmp/ipykernel_315/1845445468.py", line 6
#     print("Age next year"
#                          ^
# SyntaxError: incomplete input

# %% [markdown]
# ## Task 3 – Working with Lists
#
# Create a list containing the following numbers:
#
# 22
# 80
# 443
# 21
# 25
#
# Then perform the following operations:
#
# - Print the first element of the list
# - Print the last element of the list
# - Print the total number of elements in the list

# %%
list_of_numbers = [1907,18,8,165]
print("first element :",list_of_numbers[0])
print("last element : ",list_of_numbers[-1])
# Out:
# first element : 1907
# last element :  165

# %% [markdown]
# ## Task 4 – Modifying Lists
#
# Create a list of three programming languages.
#
# Then:
#
# - Add one new language to the list
# - Print the updated list
# - Print how many elements the list contains

# %%
languages = ["C" , "C++" , "Python"]
languages.append("R")
 print(updated_list)

# %% [markdown]
# ## Task 5 – Introduction to Sets
#
# Create a list containing the following IP addresses:
#
# 192.168.1.1
# 192.168.1.2
# 192.168.1.1
# 10.0.0.5
# 10.0.0.5
#
# Convert this list into a **set**.
#
# Print the set.

# %%
ipp_add = ["192.168.1.1",
"192,168.1.2"
192.168.1.1
10.0.0.5
10.0.0.5]
print

# %% [markdown]
# ## Task 5 – Introduction to Sets
#
# Create a list containing the following IP addresses:
#
# 192.168.1.1
# 192.168.1.2
# 192.168.1.1
# 10.0.0.5
# 10.0.0.5
#
# Convert this list into a **set**.
#
# Print the set.

# %% [markdown]
# ## Task 6 – Unique Values
#
# Using the set created in the previous task:
#
# - Print each IP address on a separate line
# - Print how many unique IP addresses exist

# %%
# Task 5'teki ip_add değişkeninin tanımlanmamış olması nedeniyle NameError oluştu.
# Bu hücredeki hatayı düzeltmek için ip_add'ı burada tanımlıyoruz.
# Normalde, bu değişkenin Task 5'teki (f3c4c6af hücresi) kodu düzeltildikten sonra gelmesi beklenir.
ip_list = ["192.168.1.1", "192.168.1.2", "192.168.1.1", "10.0.0.5", "10.0.0.5"]
ip_add = set(ip_list)

for ip in ip_add:
  print(ip)
print("Benzersiz IP adreslerinin sayısı:", len(ip_add))
# Out:
# 192.168.1.2
# 192.168.1.1
# 10.0.0.5
# Benzersiz IP adreslerinin sayısı: 3

# %% [markdown]
# ## Task 7 – User Input with Lists
#
# Ask the user to enter **five IP addresses**.
#
# Store them in a list.
#
# Then:
#
# - Convert the list into a set
# - Print the unique IP addresses
# - Print the total number of unique IP addresses

# %%
ip_add_list = []

for i in range(5):
  ip = input("Enter ip address:")
  ip_add_list.append(ip)
  unique_ips = set(ip_add_list)
  print("unique ips")
  for ip in unique ips :
   print(ip)
